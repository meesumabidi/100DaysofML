# %% [markdown]
# <a href="https://colab.research.google.com/github/meesumabidi/100DaysofML/blob/main/100daysofML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from sklearn.metrics import confusion_matrix

# %%
#salary_model
def salary_model(y_new):
    xs = [0,1,2,3,4,5,6] # number of year
    ys = [0.5,0.6,0.7,0.8,0.9,1.0,1.1] #salary 
    model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
    model.compile(optimizer="sgd", loss='mean_squared_error')
    model.fit(xs, ys, epochs=500)
    return model.predict(y_new)[0][0]

# %%
prediction = salary_model([8.0])
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 225ms/step - loss: 32.9482
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 17.3613
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 9.1495
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8232
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5439
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3430
# Epoch 7/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7103
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3770
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2013
# Epoch 10/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1087
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0599
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0342
# ...

# %%
print(prediction*100, " thousand dollars")
# Out:
# 130.68485260009766  thousand dollars
